# %% [markdown]
# # 极限

# %% [markdown]
# ## 常用函数的极限I

# %%
from sympy import *

x = symbols('x')
k = symbols('k')
a = symbols('a')
b = symbols('b')
c = symbols('c')
n = symbols('n')

functions = [
    k,
    x,
    b*x+c,
    x**n,
]

for f in functions:
    print(f"lim({f})，x趋近a时，极限为 {limit(f, x, a)}")
# Out:
# lim(k)，x趋近a时，极限为 k
# lim(x)，x趋近a时，极限为 a
# lim(b*x + c)，x趋近a时，极限为 a*b + c
# lim(x**n)，x趋近a时，极限为 a**n

# %%
from sympy import *

x = symbols('x')
n = symbols('n')
f = x**n

lmt = limit(f.subs(n, 2), x, 0)
print(f"lim({f})，n>0，x趋近0时，极限为 {lmt}")

lmt = limit(f.subs(n, -2), x, oo)
print(f"lim({f})，n<0，x趋近oo时，极限为 {lmt}")

lmt = limit(f.subs(n, -2), x, -oo)
print(f"lim({f})，n<0，x趋近-oo时，极限为 {lmt}")

lmt = limit(f.subs(n, -2), x, 0, '+')
print(f"lim({f})，n<0，x从右边趋近0时，极限为 {lmt}")

lmt = limit(f.subs(n, -2), x, 0, '-')
print(f"lim({f})，n<0且是偶数，x从左边趋近0时，极限为 {lmt}")

lmt = limit(f.subs(n, -3), x, 0, '-')
print(f"lim({f})，n<0且是奇数，x从左边趋近0时，极限为 {lmt}")
# Out:
# lim(x**n)，n>0，x趋近0时，极限为 0
# lim(x**n)，n<0，x趋近oo时，极限为 0
# lim(x**n)，n<0，x趋近-oo时，极限为 0
# lim(x**n)，n<0，x从右边趋近0时，极限为 oo
# lim(x**n)，n<0且是偶数，x从左边趋近0时，极限为 oo
# lim(x**n)，n<0且是奇数，x从左边趋近0时，极限为 -oo

# %% [markdown]
# ### 图1

# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols('x')

p1 = plot(1 / x**1, show=False)
p1.show()

# %% [markdown]
# ### 图2

# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols('x')

p1 = plot(1 / x**4, (x, 0.01, 1), show=False, xlim=(0, 1.1), ylim=(-1000,1000))
p2 = plot(1 / x**3, (x, 0.01, 1), show=False)
p3 = plot(1 / x**2, (x, 0.01, 1), show=False)
p4 = plot(1 / x**1, (x, 0.01, 1), show=False)
p1.append(p2[0])
p1.append(p3[0])
p1.append(p4[0])
p1.show()

# %% [markdown]
# ## 极限的算数运算

# %%
from sympy import *

x = symbols('x')
k = symbols('k')
a = symbols('a')
b = symbols('b')
c = symbols('c')
n = symbols('n')

f = 1/x**2
g = sin(x)

print(f"lim({f}+{g})，x趋近a时，极限为 {limit(f+g, x, a)}")
print(f"lim({f})+lim({g})，x趋近a时，极限为 {limit(f, x, a)} + {limit(g, x, a)}")
print(f'相等：{(limit(f, x, a) + limit(g, x, a)).equals(limit(f+g, x, a))}')

print('')
print(f"lim({f}-{g})，x趋近a时，极限为 {limit(f-g, x, a)}")
print(f"lim({f})-lim({g})，x趋近a时，极限为 {limit(f, x, a)} - {limit(g, x, a)}")
print(f'相等：{(limit(f, x, a) - limit(g, x, a)).equals(limit(f-g, x, a))}')

print('')
print(f"lim({f}*{g})，x趋近a时，极限为 {limit(f*g, x, a)}")
print(f"lim({f})*lim({g})，x趋近a时，极限为 {limit(f, x, a)} * {limit(g, x, a)}")
print(f'相等：{(limit(f, x, a) * limit(g, x, a)).equals(limit(f*g, x, a))}')

print('')
print(f"lim({f}/{g})，x趋近a时，极限为 {limit(f/g, x, a)}")
print(f"lim({f})/lim({g})，x趋近a时，极限为 {limit(f, x, a)} / {limit(g, x, a)}")
print(f'相等：{(limit(f, x, a) / limit(g, x, a)).equals(limit(f/g, x, a))}')
# Out:
# lim(x**(-2)+sin(x))，x趋近a时，极限为 (a**2*sin(a) + 1)/a**2
# lim(x**(-2))+lim(sin(x))，x趋近a时，极限为 a**(-2) + sin(a)
# 相等：True
#
# lim(x**(-2)-sin(x))，x趋近a时，极限为 (-a**2*sin(a) + 1)/a**2
# lim(x**(-2))-lim(sin(x))，x趋近a时，极限为 a**(-2) - sin(a)
# 相等：True
#
# lim(x**(-2)*sin(x))，x趋近a时，极限为 sin(a)/a**2
# lim(x**(-2))*lim(sin(x))，x趋近a时，极限为 a**(-2) * sin(a)
# 相等：True
#
# lim(x**(-2)/sin(x))，x趋近a时，极限为 1/(a**2*sin(a))
# lim(x**(-2))/lim(sin(x))，x趋近a时，极限为 a**(-2) / sin(a)
# 相等：True

# %% [markdown]
# ## 常见函数的极限II

# %%
from sympy import *

x = symbols('x')
k = symbols('k')
a = symbols('a')
b = symbols('b')
c = symbols('c')
n = symbols('n')

functions = [
    sin(x)/x,
    tan(x)/x,
    (1-cos(x))/x,
    cos(x),
    E**x,
    (E**x-1)/x,
]

for f in functions:
    print(f"lim({simplify(f)})，x趋近0时，极限为 {simplify(limit(f, x, 0))}")

f1 = (x**n-a**n)/(x-a)
print(f"lim({f1})，x趋近a时，极限为 {limit(f1.subs(n, 4), x, a)}")

f2 = (1+1/x)**x
print(f"lim({simplify(f2)})，x趋近oo时，极限为 {limit(f2, x, oo)}")
# Out:
# lim(sin(x)/x)，x趋近0时，极限为 1
# lim(tan(x)/x)，x趋近0时，极限为 1
# lim((1 - cos(x))/x)，x趋近0时，极限为 0
# lim(cos(x))，x趋近0时，极限为 1
# lim(exp(x))，x趋近0时，极限为 1
# lim((exp(x) - 1)/x)，x趋近0时，极限为 1
# lim((-a**n + x**n)/(-a + x))，x趋近a时，极限为 4*a**3
# lim(((x + 1)/x)**x)，x趋近oo时，极限为 E

# %% [markdown]
# ## 复合函数的极限

# %%
from sympy import *

x = symbols('x')
a = symbols('a')


g = 1/x**2
f = 3*g
lim1 = limit(f, x, a)
print(lim1)
print(3 * limit(g, x, a))
# Out:
# 3/a**2
# 3/a**2

# %% [markdown]
# ## 有理化求极限

# %% [markdown]
# $\lim _{x\rightarrow 2}\dfrac{x-2}{x^{2}-4}=\lim _{x\rightarrow 2}\dfrac{x-2}{\left( x+2\right) \left( x-2\right)}=\lim _{x\rightarrow 2}\dfrac{1}{x+2} = \dfrac{1}{4}$

# %%
from sympy import *

x = symbols('x')

f = (x-2)/(x**2-4)
print(limit(f, x, 2))
# Out:
# 1/4

# %% [markdown]
# # 导数

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation

plt.rcParams["animation.html"] = "jshtml"
plt.ioff()
fig, ax = plt.subplots()

x = sp.symbols('x')
f = x**2 + 2*x + 1
df = sp.diff(f, x)

x_point = 1
y_point = f.subs(x, x_point)
slope_at_point = df.subs(x, x_point)

start = 2
end = 0.1
frames = 11
step = (end-start) / (frames-1)


def animate(t):
    plt.cla()

    deltaX = start + step * t
    x_point2 = x_point + deltaX
    y_point2 = f.subs(x, x_point2)
    slope2 = (y_point2-y_point)/(x_point2-x_point)

    x_vals = np.linspace(-5, 5, 400)
    y_vals = [f.subs(x, val) for val in x_vals]
    plt.plot(x_vals, y_vals, label=f'$f(x) = {sp.latex(f)}$')

    y_intercept = y_point - slope2 * x_point
    x_line = np.linspace(x_point-1, x_point2+1, 10)
    y_line = slope2 * x_line + y_intercept
    plt.plot(x_line, y_line, '--g', label='line of 2 points')

    x_line = np.linspace(x_point - 1, x_point + 1, 10)
    y_line = [slope_at_point * (val - x_point) + y_point for val in x_line]
    plt.plot(x_line, y_line, 'r--', label='derivative line')

    plt.scatter([x_point, x_point2], [y_point, y_point2], color='g')

    plt.ylim(-1, 40)
    plt.legend()
    plt.grid(True)


matplotlib.animation.FuncAnimation(fig, animate, frames=frames)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img19893f07194749a5bc04999db2f8c2ab">
#   <div class="anim-controls">
#     <input id="_anim_slider19893f07194749a5bc04999db2f8c2ab" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim19893f07194749a5bc04999db2f8c2ab.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim19893f07194749a5bc04999db2f8c2ab.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim19893f07194749a5bc04999db2f8c2ab.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim19893f07194749a5bc04999db2f8c2ab.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim19893f07194749a5bc04999db2f8c2ab.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim19893f07194749a5bc04999db2f8c2ab.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim19893f07194749a5bc04999db2f8c2ab.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim19893f07194749a5bc04999db2f8c2ab.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim19893f07194749a5bc04999db2f8c2ab.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim19893f07194749a5bc04999db2f8c2ab.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select19893f07194749a5bc04999db2f8c2ab"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_19893f07194749a5bc04999db2f8c2ab"
#              >
#       <label for="_anim_radio1_19893f07194749a5bc04999db2f8c2ab">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_19893f07194749a5bc04999db2f8c2ab"
#              checked>
#       <label for="_anim_radio2_19893f07194749a5bc04999db2f8c2ab">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_19893f07194749a5bc04999db2f8c2ab"
#              >
#       <label for="_anim_radio3_19893f07194749a5bc04999db2f8c2ab">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img19893f07194749a5bc04999db2f8c2ab";
#     var slider_id = "_anim_slider19893f07194749a5bc04999db2f8c2ab";
#     var loop_select_id = "_anim_loop_select19893f07194749a5bc04999db2f8c2ab";
#     var frames = new Array(11);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy80BEi2AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABxuElEQ

# %% [markdown]
# # sympy

# %% [markdown]
# ## 符号

# %%
from sympy import *

print('符号与表达式')
x = symbols('x')
expr = x + 1
print(expr)
print(expr.subs(x, 2))

a, b, c = symbols('a b c')
f = a + b + c
print(f)
display(Eq(a+b+c, 0))

f1 = x**2 + 4*x + 4
f2 = (x+2)**2
f3 = 3*x

print('\n判定相等')
print(f1 == f2)
print(f1.equals(f2))

print('\n化简')
a = (x + 1)**2
b = x**2 + 2*x + 1
print(a - b)
print(simplify(a-b))
# Out:
# 符号与表达式
# x + 1
# 3
# a + b + c
# a + b + c = 0
# 判定相等
# False
# True
#
# 化简
# -x**2 - 2*x + (x + 1)**2 - 1
# 0

# %% [markdown]
# ## 作图

# %%
from sympy import symbols, cos, sin
from sympy.plotting import plot3d_parametric_line
u = symbols('u')

plot3d_parametric_line(cos(u), sin(u), u, (u, -5, 5))

# %% [markdown]
# ## Latex

# %%
from sympy import *
x, t, z, nu = symbols('x t z nu')
init_printing(use_unicode=True)

a = diff(sin(x)*exp(x), x)
display(a)
print(a)

print(latex(diff(sin(x)*exp(x), x)))
# Out:
#  x           x
# ℯ ⋅sin(x) + ℯ ⋅cos(x)
# exp(x)*sin(x) + exp(x)*cos(x)
# e^{x} \sin{\left(x \right)} + e^{x} \cos{\left(x \right)}
